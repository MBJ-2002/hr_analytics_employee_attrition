# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, ConfusionMatrixDisplay
import joblib
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
df = pd.read_csv('../dataset/dataset.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
#  14  JobLevel                  1470 non-null   int64
#  15  JobRole                   1470 non-null   object
#  16  JobSatisfaction           1470 non-null   int64
#  17  MaritalStatus             1470 non-null   object
#  18  MonthlyIncome             1470 non-null   int64
#  19  MonthlyRate               1470 non-null   int64
#  20  NumCompaniesWorked        1470 non-null   int64
#  21  Over18                    1470 non-null   object
#  22  OverTime                  1470 non-null   object
#  23  PercentSalaryHike         1470 non-null   int64
#  24  PerformanceRating         1470 non-null   int64
#  25  RelationshipSatisfaction  1470 non-null   int64
#  26  StandardHours             1470 non-null   int64
#  27  StockOptionLevel          1470 non-null   int64
#  28  TotalWorkingYears         1470 non-null   int64
#  29  TrainingTimesLastYear     1470 non-null   int64
#  30  WorkLifeBalance           1470 non-null   int64
#  31  YearsAtCompany            1470 non-null   int64
#  32  YearsInCurrentRole        1470 non-null   int64
#  33  YearsSinceLastPromotion   1470 non-null   int64
#  34  YearsWithCurrManager      1470 non-null   int64
# dtypes: int64(26), object(9)
# memory usage: 402.1+ KB

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df = df.drop(columns=['Over18','StandardHours','EmployeeNumber','EmployeeCount'])

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         1                 0
# 1    Male  ...                  4                         4                 1
# 2    Male  ...                  3                         2                 0
# 3  Female  ...                  3                         3                 0
# 4    Male  ...                  3                         4                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                      0               1               6
# 1                10                      3               3              10
# 2                 7                      3               3               0
# 3                 8                      3               3               8
# 4                 6                      3               3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   4                        0                    5
# 1                   7                        1                    7
# 2                   0                        0                    0
# 3                   7                        3                    0
# 4                   2                        2                    2
#
# [5 rows x 31 columns]

# %%
df['Attrition'] = df['Attrition'].str.strip().str.capitalize()
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})

# %%
X = df.drop('Attrition', axis=1)
y = df['Attrition']

# %%
cat_cols = ['BusinessTravel', 'Department', 'EducationField', 'Gender',
            'JobRole', 'MaritalStatus', 'OverTime']
num_cols = [col for col in X.columns if col not in cat_cols]

# %%
X = pd.get_dummies(X, columns=cat_cols, drop_first=True)

# %%
X.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# 0          94               3         2                4           5993  ...
# 1          61               2         2                2           5130  ...
# 2          92               2         1                3           2090  ...
# 3          56               3         1                3           2909  ...
# 4          40               3         1                2           3468  ...
#
#    JobRole_Laboratory Technician  JobRole_Manager  \
# 0                          False            False
# 1                          False            False
# 2                           True            False
# 3                          False            False
# 4                           True            False
#
#    JobRole_Manufacturing Director  JobRole_Research Director  \
# 0                           False                      False
# 1                           False                      False
# 2                           False                      False
# 3                           False                      False
# 4                           False                      False
#
#    JobRole_Research Scientist  JobRole_Sales Executive  \
# 0                       False                     True
# 1                        True                    False
# 2                       False                    False
# 3                        True                    False
# 4                       False                    False
#
#    JobRole_Sales Representative  MaritalStatus_Married  MaritalStatus_Single  \
# 0                         False                  False                  True
# 1                         False                   True                 False
# 2                         False                  False                  True
# 3                         False                   True                 False
# 4                         False                   True                 False
#
#    OverTime_Yes
# 0          True
# 1         False
# 2          True
# 3          True
# 4         False
#
# [5 rows x 44 columns]

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm',linewidths=0.1)
plt.title('Correlation Matrix overview')

plt.show()

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.20,random_state=42)

# %%
svc = SVC(kernel='linear')

# %%
svc.fit(X_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svc.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No','Yes'])
disp.plot(cmap='Blues')

print("Accuracy:", accuracy_score(y_test, y_pred))
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.891156462585034
# [[246   9]
#  [ 23  16]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       255
#            1       0.64      0.41      0.50        39
#
#     accuracy                           0.89       294
#    macro avg       0.78      0.69      0.72       294
# weighted avg       0.88      0.89      0.88       294

# %%
param_grid = {'C': [0.1,0.01, 1,10,100,1000],
              'gamma': [1,0.1,0.01,0.001,0.0001],
              'kernel': ['linear']}

# %%
grid=GridSearchCV(SVC(),param_grid=param_grid,refit=True,cv=5,verbose=3)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.856 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.898 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.864 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.872 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.872 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.856 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.898 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.864 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.872 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.872 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.856 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.898 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.864 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.872 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.872 total time=   0.0s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.856 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.898 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.864 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.872 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.872 total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.856 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.898 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.864 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.872 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.872 total time=   0.0s
# [CV 1/5] END ....C=0.01, gamma=1, kernel=linear;, score=0.839 total time=   0.0s
# [CV 2/5] END ....C=0.01, gamma=1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END ....C=0.01, gamma=1, kernel=linear;, score=0.851 total time=   0.0s
# [CV 4/5] END ....C=0.01, gamma=1, kernel=linear;, score=0.864 total time=   0.0s
# [CV 5/5] END ....C=0.01, gamma=1, kernel=linear;, score=0.834 total time=   0.0s
# [CV 1/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.839 total time=   0.0s
# [CV 2/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.838 total time=   0.0s
# [CV 3/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.851 total time=   0.0s
# [CV 4/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.864 total time=   0.0s
# [CV 5/5] END ..C=0.01, gamma=0.1, kernel=linear;, score=0.834 total time=   0.0s
# [CV 1/5] END .C=0.01, gamma=0.01, kernel=linear;, score=0.839 total time=   0.0s
# [CV 2/5] END .C=0.01, gamma=0.01, kernel=linear;, score=0.838 total time=   0.0s
5] END ....C=10, gamma=0.1, kernel=linear;, score=0.847 total time=   0.8s
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.894 total time=   0.5s
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.847 total time=   0.7s
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.877 total time=   0.7s
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.851 total time=   0.9s
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.847 total time=   0.8s
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.894 total time=   0.6s
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.847 total time=   0.7s
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.877 total time=   0.6s
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.851 total time=   1.0s
# [CV 1/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.847 total time=   0.9s
# [CV 2/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.894 total time=   0.6s
# [CV 3/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.847 total time=   0.7s
# [CV 4/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.877 total time=   0.7s
# [CV 5/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.851 total time=   0.8s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.847 total time=   0.8s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.894 total time=   0.5s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.847 total time=   0.7s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.877 total time=   0.6s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.851 total time=   0.8s
# [CV 1/5] END .....C=100, gamma=1, kernel=linear;, score=0.847 total time=   6.8s
# [CV 2/5] END .....C=100, gamma=1, kernel=linear;, score=0.894 total time=   3.0s
# [CV 3/5] END .....C=100, gamma=1, kernel=linear;, score=0.847 total time=   6.1s
# [CV 4/5] END .....C=100, gamma=1, kernel=linear;, score=0.877 total time=   5.2s
# [CV 5/5] END .....C=100, gamma=1, kernel=linear;, score=0.851 total time=   6.8s
# [CV 1/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.847 total time=   6.7s
# [CV 2/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.894 total time=   2.9s
# [CV 3/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.847 total time=   6.0s
# [CV 4/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.877 total time=   5.1s
# [CV 5/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.851 total time=   6.9s
# [CV 1/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.847 total time=   6.7s
# [CV 2/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.894 total time=   2.9s
# [CV 3/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.847 total time=   6.1s
# [CV 4/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.877 total time=   5.1s
# [CV 5/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.851 total time=   6.8s
# [CV 1/5] END .C=100, gamma=0.001, kernel=linear;, score=0.847 total time=   6.7s
# [CV 2/5] END .C=100, gamma=0.001, kernel=linear;, score=0.894 total time=   2.9s
# [CV 3/5] END .C=100, gamma=0.001, kernel=linear;, score=0.847 total time=   6.1s
# [CV 4/5] END .C=100, gamma=0.001, kernel=linear;, score=0.877 total time=   5.2s
# [CV 5/5] END .C=100, gamma=0.001, kernel=linear;, score=0.851 total time=   6.8s
# [CV 1/5] END C=100, gamma=0.0001, kernel=linear;, score=0.847 total time=   6.6s
# [CV 2/5] END C=100, gamma=0.0001, kernel=linear;, score=0.894 total time=   2.9s
# [CV 3/5] END C=100, gamma=0.0001, kernel=linear;, score=0.847 total time=   6.1s
# [CV 4/5] END C=100, gamma=0.0001, kernel=linear;, score=0.877 total time=   5.1s
# [CV 5/5] END C=100, gamma=0.0001, kernel=linear;, score=0.851 total time=   6.8s
# [CV 1/5] END ....C=1000, gamma=1, kernel=linear;, score=0.847 total time= 1.5min
# [CV 2/5] END ....C=1000, gamma=1, kernel=linear;, score=0.894 total time=  41.1s
# [CV 3/5] END ....C=1000, gamma=1, kernel=linear;, score=0.847 total time=  53.1s
# [CV 4/5] END ....C=1000, gamma=1, kernel=linear;, score=0.877 total time=  50.5s
# [CV 5/5] END ....C=1000, gamma=1, kernel=linear;, score=0.855 total time=  37.3s
# [CV 1/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.847 total time= 1.5min
# [CV 2/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.894 total time=  40.6s
# [CV 3/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.847 total time=  51.3s
# [CV 4/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.877 total time=  48.8s
# [CV 5/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.855 total time=  36.6s
# [CV 1/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.847 total time= 1.5min
# [CV 2/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.894 total time=  40.8s
# [CV 3/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.847 total time=  51.2s
# [CV 4/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.877 total time=  48.9s
# [CV 5/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.855 total time=  36.3s
# [CV 1/5] END C=1000, gamma=0.001, kernel=linear;, score=0.847 total time= 1.5min
# [CV 2/5] END C=1000, gamma=0.001, kernel=linear;, score=0.894 total time=  40.9s
# [CV 3/5] END C=1000, gamma=0.001, kernel=linear;, score=0.847 total time=  51.2s
# [CV 4/5] END C=1000, gamma=0.001, kernel=linear;, score=0.877 total time=  48.8s
# [CV 5/5] END C=1000, gamma=0.001, kernel=linear;, score=0.855 total time=  36.4s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.847 total time= 1.5min
# [CV 2/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.894 total time=  41.2s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.847 total time=  51.6s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.877 total time=  48.6s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.855 total time=  36.2s
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.1, 0.01, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['linear']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}

# %%
y_pred4 = grid.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred4)

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['No','Yes'])
disp.plot(cmap='Blues')

print("Accuracy:", accuracy_score(y_test, y_pred))
print(cm)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.891156462585034
# [[248   7]
#  [ 23  16]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.96      0.94       255
#            1       0.64      0.41      0.50        39
#
#     accuracy                           0.89       294
#    macro avg       0.78      0.69      0.72       294
# weighted avg       0.88      0.89      0.88       294
