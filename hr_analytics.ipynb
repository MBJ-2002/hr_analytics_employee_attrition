# %%
import pandas as pd
import numpy as np

df = pd.read_csv('dataset/dataset.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df['Attrition'].value_counts()
# Out:
# Attrition
# No     1233
# Yes     237
# Name: count, dtype: int64

# %%
df['Attrition'].value_counts().plot(kind='bar', color='red')
# Out:
# <Axes: xlabel='Attrition'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#Mapping attrition to 0 and 1 for correlation matrix plot

#First remove white spaces from attrition column like " yes" -> "yes" Then Capitalize it "yes" -> "Yes"

df['Attrition'] = df['Attrition'].str.strip().str.capitalize()
df['Attrition'] = df['Attrition'].map({'Yes': 1, 'No': 0})

#Dropping two columns StandardHours and EmployeeCount as the Standard hours are 80 for all rows and same goes for employee count too

df = df.drop(['EmployeeCount', 'StandardHours'], axis=1)

corr = df.corr(numeric_only=True)

plt.figure(figsize=(12,8))

sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm',linewidths=0.1)

plt.title('Correlation Matrix overview')

plt.show()

# %%
# Analysing age frequency of dataset

sns.histplot(df['Age'], kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
# Box plot between Attrition and Income to see any outliers
# We can observe several outlier points in this graph

sns.boxplot(x='Attrition', y='MonthlyIncome', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='MonthlyIncome'>

# %%
# Dropping useless columns before splitting dataset

# I had already dropped Employee count and standard hours before

dc = ['Over18', 'EmployeeNumber']
df = df.drop(columns=dc, errors='ignore')

# %%
# Axis = 1 so that specific column is removed

X = df.drop('Attrition', axis=1)
y = df['Attrition']

# %%
# Splitting category columns and numeric value columns so we can encode it further

cat_cols = ['BusinessTravel', 'Department', 'EducationField', 'Gender',
            'JobRole', 'MaritalStatus', 'OverTime']
num_cols = [col for col in X.columns if col not in cat_cols]

# %%
X = pd.get_dummies(X, columns=cat_cols, drop_first=True)

# %%
X.head()
